# %% [markdown]
# # Dating App EDA

# %% [markdown]
# ## Takeaways
# <ul>
#     <li>Data is clean. No duplicates</li>
# </ul>

# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sn
from datetime import datetime, date

# %%
# Import Data
users = pd.read_csv("Data/users.csv")
messages = pd.read_csv("Data/messages.csv")
reports = pd.read_csv("Data/reports.csv")

# %% [markdown]
# ## Quality Check

# %%
# Look at data

print(f"Users:\n{users.head()}\n---\nMessages:\n{messages.head()}\n---\nReports:\n{reports.head()}")
# Out:
# Users:
#    user_id  start_date  is_verified     gender   region device_os  \
# 0     1001  2023-01-31            0          F   Canada       iOS
# 1     1002  2023-12-30            0  Nonbinary  Nigeria   Android
# 2     1003  2022-05-10            0          M       US   Android
# 3     1004  2023-07-18            0          M   Canada       iOS
# 4     1005  2023-02-04            1          M       US   Android
#
#   platform_package
# 0             base
# 1             base
# 2             base
# 3             base
# 4             gold
# ---
# Messages:
#    message_id  sender_id  receiver_id            timestamp  \
# 0       50001       1283         1019  2025-01-02 07:17:00
# 1       50002       1136         1471  2025-01-18 13:58:00
# 2       50003       1467         1311  2025-01-05 21:33:00
# 3       50004       1380         1358  2025-01-27 07:29:00
# 4       50005       1362         1374  2025-01-30 08:44:00
#
#                                 message_text
# 0               Can we talk outside the app?
# 1               Can we talk outside the app?
# 2  Crypto is a great investment opportunity.
# 3       Hello dear, can I ask you something…
# 4                          Hey, how are you?
# ---
# Reports:
#    report_id  reporter_id  reported_user_id        category   timestamp
# 0       9001         1190              1352  financial_scam  2025-07-14
# 1       9002         1471              1085            spam  2025-02-01
# 2       9003         1288              1105      harassment  2025-01-20
# 3       9004         1424              1426      catfishing  2024-08-21
# 4       9005         1397              1335  financial_scam  2025-05-24

# %% [markdown]
# ### Users

# %%
users.isna().sum()
# Out:
# user_id             0
# account_age_days    0
# is_verified         0
# gender              0
# region              0
# device_os           0
# dtype: int64

# %%
users.describe()
# Out:
#            user_id  account_age_days  is_verified
# count   500.000000        500.000000   500.000000
# mean   1250.500000       1031.674000     0.288000
# std     144.481833        570.153346     0.453285
# min    1001.000000          1.000000     0.000000
# 25%    1125.750000        554.500000     0.000000
# 50%    1250.500000       1059.500000     0.000000
# 75%    1375.250000       1509.250000     1.000000
# max    1500.000000       1998.000000     1.000000

# %%
users.user_id.nunique()
# Out:
# 500

# %% [markdown]
# ### Messages

# %%
messages.isna().sum()
# Out:
# message_id      0
# sender_id       0
# receiver_id     0
# timestamp       0
# message_text    0
# dtype: int64

# %%
messages.describe()
# Out:
#          message_id    sender_id  receiver_id
# count   1000.000000  1000.000000  1000.000000
# mean   50500.500000  1255.859000  1243.488000
# std      288.819436   144.034409   146.413978
# min    50001.000000  1001.000000  1001.000000
# 25%    50250.750000  1128.000000  1113.000000
# 50%    50500.500000  1262.000000  1237.000000
# 75%    50750.250000  1383.000000  1371.250000
# max    51000.000000  1500.000000  1500.000000

# %%
print(messages.sender_id.nunique(), messages.receiver_id.nunique(), messages.message_id.nunique())
# Out:
# 429 434 1000

# %% [markdown]
# ### Reports

# %%
reports.isna().sum()
# Out:
# report_id           0
# reporter_id         0
# reported_user_id    0
# category            0
# timestamp           0
# dtype: int64

# %%
reports.describe
# Out:
# <bound method NDFrame.describe of     report_id  reporter_id  reported_user_id        category  \
# 0        9001         1403              1202      catfishing
# 1        9002         1404              1212  financial_scam
# 2        9003         1100              1006            spam
# 3        9004         1163              1112      harassment
# 4        9005         1416              1376            spam
# ..        ...          ...               ...             ...
# 95       9096         1424              1121      harassment
# 96       9097         1378              1298      catfishing
# 97       9098         1096              1466      catfishing
# 98       9099         1457              1054      harassment
# 99       9100         1229              1331  financial_scam
#
#               timestamp
# 0   2025-01-05 20:24:00
# 1   2025-01-15 01:28:00
# 2   2025-01-01 19:07:00
# 3   2025-01-03 18:41:00
# 4   2025-01-25 19:40:00
# ..                  ...
# 95  2025-01-17 07:04:00
# 96  2025-01-03 11:13:00
# 97  2025-01-05 02:17:00
# 98  2025-01-25 03:04:00
# 99  2025-01-21 14:24:00
#
# [100 rows x 5 columns]>

# %%
reports['timestamp_dt'] = pd.to_datetime(reports['timestamp'])

# %% [markdown]
# ## Join Data

# %%
base = pd.merge(users, reports, left_on='user_id', right_on='reported_user_id', how='left')
base.head()
# Out:
#    user_id  start_date  is_verified     gender   region device_os  \
# 0     1001  2023-01-31            0          F   Canada       iOS
# 1     1002  2023-12-30            0  Nonbinary  Nigeria   Android
# 2     1003  2022-05-10            0          M       US   Android
# 3     1004  2023-07-18            0          M   Canada       iOS
# 4     1005  2023-02-04            1          M       US   Android
#
#   platform_package  report_id  reporter_id  reported_user_id category  \
# 0             base        NaN          NaN               NaN      NaN
# 1             base        NaN          NaN               NaN      NaN
# 2             base        NaN          NaN               NaN      NaN
# 3             base        NaN          NaN               NaN      NaN
# 4             gold        NaN          NaN               NaN      NaN
#
#   timestamp
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
base['age_on_report'] = pd.to_datetime(base[base.report_id.notna()]['timestamp']) - pd.to_datetime(base[base.report_id.notna()]['start_date'])

# %%
base['age_on_report'] = datetime.strptime(base[base.timestamp.notna()].timestamp, '%Y-%m-%d').date() - datetime.strptime(base[base.timestamp.notna()].start_date[7], '%Y-%m-%d').date()
base.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-f5e2c9d459bc> in <module>
# ----> 1 base['age_on_report'] = datetime.strptime(base[base.timestamp.notna()].timestamp, '%Y-%m-%d').date() - datetime.strptime(base[base.timestamp.notna()].start_date[7], '%Y-%m-%d').date()
#       2 base.head()
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
base[base.report_id.notna()].head()
# Out:
#     user_id  start_date  is_verified     gender       region device_os  \
# 7      1008  2022-11-10            0  Nonbinary        India       iOS
# 12     1013  2020-11-26            1          F       Canada       iOS
# 23     1024  2020-12-09            1          F       Canada   Android
# 27     1028  2021-01-20            1          M           US       iOS
# 28     1029  2023-04-30            0          M  Philippines   Android
#
#    platform_package  report_id  reporter_id  reported_user_id        category  \
# 7              base     9095.0       1240.0            1008.0      catfishing
# 12           silver     9021.0       1072.0            1013.0            spam
# 23           silver     9078.0       1397.0            1024.0      harassment
# 27             gold     9065.0       1212.0            1028.0  financial_scam
# 28             base     9052.0       1326.0            1029.0  financial_scam
#
#      timestamp
# 7   2025-02-15
# 12  2024-07-20
# 23  2025-01-16
# 27  2024-08-19
# 28  2024-07-03

# %%
base.describe()
# Out:
#            user_id  is_verified    report_id  reporter_id  reported_user_id
# count   510.000000   510.000000   100.000000   100.000000        100.000000
# mean   1250.325490     0.294118  9050.500000  1246.350000       1266.850000
# std     144.383779     0.456092    29.011492   143.166949        146.266007
# min    1001.000000     0.000000  9001.000000  1008.000000       1008.000000
# 25%    1126.250000     0.000000  9025.750000  1114.250000       1145.500000
# 50%    1249.500000     0.000000  9050.500000  1218.500000       1257.500000
# 75%    1374.750000     1.000000  9075.250000  1369.500000       1394.750000
# max    1500.000000     1.000000  9100.000000  1500.000000       1499.000000

# %%
base.groupby(base[base.report_id.notna()]['gender'])['account_age_days'].agg(['mean', 'median', 'std', 'sum'])
# Out:
#                   mean  median         std    sum
# gender
# F          1060.061224  1060.0  577.117168  51943
# M          1121.452381  1168.5  559.778057  47101
# Nonbinary   818.333333   751.0  693.354166   7365

# %%
base.groupby(base['gender'])['account_age_days'].agg(['min', 'max', 'mean', 'median', 'std', 'sum'])
# Out:
#            min   max         mean  median         std     sum
# gender
# F            1  1981  1046.308943  1104.0  570.523671  257392
# M            1  1998  1034.014354  1038.0  573.580702  216109
# Nonbinary   16  1981   966.557692   954.5  558.867006   50261
