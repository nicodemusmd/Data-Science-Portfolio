# %%
import pandas as pd
import numpy as np
import random as rd
import seaborn as sn
import matplotlib.pyplot as plt
# from ucimlrepo import fetch_ucirepo

# %%
df = pd.read_csv("Data/default of credit card clients.csv")

# %%
# Look at first 5 rows
df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
# drop first row
defaults = df.drop(index=0)
defaults = defaults.drop("Unnamed: 0", axis = 1)
defaults.head()
# Out:
#        X1 X2 X3 X4  X5  X6 X7  X8  X9 X10  ...    X15    X16    X17   X18  \
# 1   20000  2  2  1  24   2  2  -1  -1  -2  ...      0      0      0     0
# 2  120000  2  2  2  26  -1  2   0   0   0  ...   3272   3455   3261     0
# 3   90000  2  2  2  34   0  0   0   0   0  ...  14331  14948  15549  1518
# 4   50000  2  2  1  37   0  0   0   0   0  ...  28314  28959  29547  2000
# 5   50000  1  2  1  57  -1  0  -1   0   0  ...  20940  19146  19131  2000
#
#      X19    X20   X21   X22   X23  Y
# 1    689      0     0     0     0  1
# 2   1000   1000  1000     0  2000  1
# 3   1500   1000  1000  1000  5000  0
# 4   2019   1200  1100  1069  1000  0
# 5  36681  10000  9000   689   679  0
#
# [5 rows x 24 columns]

# %%
#Convert datatypes from string to ints
defaults = defaults.astype(int)
type(defaults.iloc[1,1])
# Out:
# numpy.int32

# %%
# Look at distributions of data
defaults.hist(bins = 20, figsize=(20,15))
plt.show()

# %%
defaults_transformed = defaults
fields_to_transform = ["X1", "X5", "X15","X3", "X22"]
defaults_transformed[fields_to_transform] = defaults_transformed[fields_to_transform].apply(lambda x: np.log(x))
defaults_transformed.hist(bins = 20, figsize = (20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000175D20F7BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D0373D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1F2CAF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D2A38370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1AE4F70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1B74820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1B74130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D2B59C70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1C5FC10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1CC45B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000175D21C9A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D2222F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D2B78F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1FE73D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1FAED90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1CB58E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D215ED00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1E3A3A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1A2D760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1B7B220>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1C6ACA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D1C9B220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D20150A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D21667C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000175D22E8E80>]],
#       dtype=object)
